# %%
import pandas as pd

# %%
age = pd.read_csv('family_person_age.txt', delimiter = '\t') #TXT to CSV by pandas
cnt = pd.read_csv('family_person_cnt.txt', delimiter = '\t') #TXT to CSV by pandas
uni = pd.read_csv('univ_students.txt', delimiter = '\t')# https://data.seoul.go.kr/dataList/10833/S/2/datasetView.do#

# %%
age
# Out:
#       기간   구분  성별         합계   20세미만   20~24세   25~29세   30~34세   35~39세  \
# 0   2018   합계   계  1,229,421  14,487  109,213  195,284  155,740  118,254
# 1   2018   합계  남자    581,944   5,629   39,816   97,792   87,035   66,348
# 2   2018   합계  여자    647,477   8,858   69,397   97,492   68,705   51,906
# 3   2018  종로구   계     25,326     798    3,741    4,007    2,587    1,880
# 4   2018  종로구  남자     12,635     304    1,761    2,259    1,441      976
# ..   ...  ...  ..        ...     ...      ...      ...      ...      ...
# 73  2018  송파구  남자     28,740     159      900    4,092    5,162    4,017
# 74  2018  송파구  여자     34,711     127    1,784    5,282    4,904    3,958
# 75  2018  강동구   계     42,126     144    1,580    4,861    4,839    4,242
# 76  2018  강동구  남자     20,404      64      489    2,273    2,700    2,468
# 77  2018  강동구  여자     21,722      80    1,091    2,588    2,139    1,774
#
#     40~44세  45~49세  50~54세  55~59세  60~64세  65~69세  70~74세  75~79세  80~84세  \
# ...

# %%
cnt
# Out:
#           기간  자치구     동      전체세대수       1인세대     2인세대     3인세대     4인세대  \
# 0    2020.06   합계    합계  4,384,076  1,810,878  940,220  767,670  668,740
# 1    2020.06  종로구     계     74,497     37,503   14,341   10,697    8,837
# 2    2020.06  종로구   사직동      4,717      2,373      935      673      536
# 3    2020.06  종로구   삼청동      1,370        729      252      182      140
# 4    2020.06  종로구   부암동      4,346      1,686      972      745      689
# ..       ...  ...   ...        ...        ...      ...      ...      ...
# 446  2020.06  강동구  둔촌1동        161        114       18       11       14
# 447  2020.06  강동구  둔촌2동     11,234      3,676    2,581    2,299    2,152
# 448  2020.06  강동구  암사1동     16,179      6,343    3,762    3,047    2,402
# 449  2020.06  강동구  천호2동     17,754      8,750    3,988    2,639    1,837
# 450  2020.06  강동구    길동     21,282      8,895    4,652    3,808    2,954
#
#         5인세대    6인세대   7인세대   8인세대 9인세대 10인세대 이상
# ...

# %%
uni
# Out:
#       기간 행정구역별       합계       남자       여자
# 0   2020    합계  414,524  205,290  209,234
# 1   2020   종로구    8,276    4,144    4,132
# 2   2020    중구    4,788    2,101    2,687
# 3   2020   용산구    8,429    4,113    4,316
# 4   2020   성동구   13,539    6,574    6,965
# 5   2020   광진구   15,155    7,340    7,815
# 6   2020  동대문구   15,886    7,434    8,452
# 7   2020   중랑구   15,227    7,761    7,466
# 8   2020   성북구   21,335    9,919   11,416
# 9   2020   강북구   12,724    6,227    6,497
# 10  2020   도봉구   14,201    7,198    7,003
# 11  2020   노원구   28,474   14,474   14,000
# 12  2020   은평구   20,596   10,401   10,195
# 13  2020  서대문구   14,523    6,875    7,648
# 14  2020   마포구   14,769    6,938    7,831
# 15  2020   양천구   21,815   11,267   10,548
# 16  2020   강서구   22,970   11,427   11,543
# 17  2020   구로구   15,836    8,265    7,571
# 18  2020   금천구    9,046    4,522    4,524
# 19  2020  영등포구   12,777    6,471    6,306
# 20  2020   동작구   16,643    8,005    8,638
# ...

# %%
# file=file.rename(columns={"기간":"Time","자치구":"Gu","동":"Dong","일반가구":"Total","일반가구.1":"1","일반가구.2":"2","일반가구.3":3,"일반가구.4":"4","일반가구.5":"5","일반가구.6":"6","일반가구.7":"7"})

# %%
# file.drop([0],inplace=True)#columns

# %%
cnt['자치구'].unique()
# Out:
# array(['합계', '종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구',
#        '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구',
#        '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype=object)

# %%
age['구분'].unique()
# Out:
# array(['합계', '종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구',
#        '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구',
#        '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype=object)
